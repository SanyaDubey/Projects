# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt
import warnings
warnings.filterwarnings('ignore')

# %%
import pandas as pd
df_sonar=pd.read_csv('Sonar_Dataset.csv')
df_sonar

# The target variable is M = Mines or R = Rocks based on the 60 attributes and values.
# Out:
#          a1      a2      a3      a4      a5      a6      a7      a8      a9  \
# 0    0.0200  0.0371  0.0428  0.0207  0.0954  0.0986  0.1539  0.1601  0.3109
# 1    0.0453  0.0523  0.0843  0.0689  0.1183  0.2583  0.2156  0.3481  0.3337
# 2    0.0262  0.0582  0.1099  0.1083  0.0974  0.2280  0.2431  0.3771  0.5598
# 3    0.0100  0.0171  0.0623  0.0205  0.0205  0.0368  0.1098  0.1276  0.0598
# 4    0.0762  0.0666  0.0481  0.0394  0.0590  0.0649  0.1209  0.2467  0.3564
# ..      ...     ...     ...     ...     ...     ...     ...     ...     ...
# 203  0.0187  0.0346  0.0168  0.0177  0.0393  0.1630  0.2028  0.1694  0.2328
# 204  0.0323  0.0101  0.0298  0.0564  0.0760  0.0958  0.0990  0.1018  0.1030
# 205  0.0522  0.0437  0.0180  0.0292  0.0351  0.1171  0.1257  0.1178  0.1258
# 206  0.0303  0.0353  0.0490  0.0608  0.0167  0.1354  0.1465  0.1123  0.1945
# 207  0.0260  0.0363  0.0136  0.0272  0.0214  0.0338  0.0655  0.1400  0.1843
#
# ...

# %%
# Let's check the data type of each variable.
df_sonar.dtypes

# Except "Class" which is of "object" type, rest all are of float64 type.
# Out:
# a1       float64
# a2       float64
# a3       float64
# a4       float64
# a5       float64
#           ...
# a57      float64
# a58      float64
# a59      float64
# a60      float64
# Class     object
# Length: 61, dtype: object

# %%
# Let's use describe function
df_sonar.describe()
# Out:
#                a1          a2          a3          a4          a5          a6  \
# count  208.000000  208.000000  208.000000  208.000000  208.000000  208.000000
# mean     0.029164    0.038437    0.043832    0.053892    0.075202    0.104570
# std      0.022991    0.032960    0.038428    0.046528    0.055552    0.059105
# min      0.001500    0.000600    0.001500    0.005800    0.006700    0.010200
# 25%      0.013350    0.016450    0.018950    0.024375    0.038050    0.067025
# 50%      0.022800    0.030800    0.034300    0.044050    0.062500    0.092150
# 75%      0.035550    0.047950    0.057950    0.064500    0.100275    0.134125
# max      0.137100    0.233900    0.305900    0.426400    0.401000    0.382300
#
#                a7          a8          a9         a10  ...         a51  \
# count  208.000000  208.000000  208.000000  208.000000  ...  208.000000
# mean     0.121747    0.134799    0.178003    0.208259  ...    0.016069
# ...

# %%
# Checking the null values using heatmap.
import seaborn as sns
import matplotlib.pyplot as plt
sns.heatmap(df_sonar.isnull())
plt.show()
# thus, there are no null values present.

# %%
# checking the null values without visualization.
df_sonar.isnull().sum()
# Out:
# a1       0
# a2       0
# a3       0
# a4       0
# a5       0
#         ..
# a57      0
# a58      0
# a59      0
# a60      0
# Class    0
# Length: 61, dtype: int64

# %%
# Checking the count of each class in target vraiables
sns.countplot(x="Class",data=df_sonar)
plt.show()

# %%
# Lets check the skewness of dataset.
df_sonar.skew()
# Out:
# a1     2.131088
# a2     2.155644
# a3     2.652518
# a4     3.401697
# a5     2.018141
# a6     1.248166
# a7     0.970820
# a8     1.481107
# a9     1.633870
# a10    1.281258
# a11    0.987813
# a12    0.588681
# a13    0.736584
# a14    1.022369
# a15    0.763964
# a16    0.694671
# a17    0.654480
# a18    0.525845
# a19    0.283182
# a20   -0.085331
# a21   -0.252741
# a22   -0.392289
# a23   -0.594350
# a24   -0.691861
# a25   -0.788909
# a26   -0.671580
# a27   -0.627843
# a28   -0.615447
# a29   -0.442007
# a30   -0.132390
# a31    0.259797
# a32    0.313420
# a33    0.423864
# a34    0.563296
# a35    0.591654
# a36    0.619868
# a37    0.676994
# a38    1.033366
# a39    0.908835
# a40    0.861280
# a41    0.863526
# a42    0.860110
# a43    0.909317
# a44    1.235086
# a45    1.366839
# a46    1.706674
# a47    1.790155
# a48    1.277722
# a49    1.273385
# a50    1.761714
# a51    2.716060
# a52    2.093976
# a53    1.060572
# a54    1.093090
# a55    1.789946
# ...

# %%
sns.distplot(df_sonar['a5'])

# %%
sns.distplot(df_sonar['a36'])

# %%
# LEt's check tha value counts for 'Survived'.
df_sonar["Class"].value_counts()
# Out:
# M    111
# R     97
# Name: Class, dtype: int64

# %%
# Let's convert the categorical variable 'Class'.

clas = pd.get_dummies(df_sonar['Class'],drop_first=True)

# %%
# Let's drop the columns Class.
df_sonar.drop(['Class'], axis = 1, inplace = True)

# %%
df_sonar.head()
# we can see that the 'Class' has been removed from the dataset.
# Out:
#        a1      a2      a3      a4      a5      a6      a7      a8      a9  \
# 0  0.0200  0.0371  0.0428  0.0207  0.0954  0.0986  0.1539  0.1601  0.3109
# 1  0.0453  0.0523  0.0843  0.0689  0.1183  0.2583  0.2156  0.3481  0.3337
# 2  0.0262  0.0582  0.1099  0.1083  0.0974  0.2280  0.2431  0.3771  0.5598
# 3  0.0100  0.0171  0.0623  0.0205  0.0205  0.0368  0.1098  0.1276  0.0598
# 4  0.0762  0.0666  0.0481  0.0394  0.0590  0.0649  0.1209  0.2467  0.3564
#
#       a10  ...     a51     a52     a53     a54     a55     a56     a57  \
# 0  0.2111  ...  0.0232  0.0027  0.0065  0.0159  0.0072  0.0167  0.0180
# 1  0.2872  ...  0.0125  0.0084  0.0089  0.0048  0.0094  0.0191  0.0140
# 2  0.6194  ...  0.0033  0.0232  0.0166  0.0095  0.0180  0.0244  0.0316
# 3  0.1264  ...  0.0241  0.0121  0.0036  0.0150  0.0085  0.0073  0.0050
# 4  0.4459  ...  0.0156  0.0031  0.0054  0.0105  0.0110  0.0015  0.0072
#
#       a58     a59     a60
# 0  0.0084  0.0090  0.0032
# 1  0.0049  0.0052  0.0044
# ...

# %%
# Let's add the dummied 'Class'.
df_sonar = pd.concat([df_sonar,clas], axis = 1)
df_sonar.head()

# the clas is added as R .
# Out:
#        a1      a2      a3      a4      a5      a6      a7      a8      a9  \
# 0  0.0200  0.0371  0.0428  0.0207  0.0954  0.0986  0.1539  0.1601  0.3109
# 1  0.0453  0.0523  0.0843  0.0689  0.1183  0.2583  0.2156  0.3481  0.3337
# 2  0.0262  0.0582  0.1099  0.1083  0.0974  0.2280  0.2431  0.3771  0.5598
# 3  0.0100  0.0171  0.0623  0.0205  0.0205  0.0368  0.1098  0.1276  0.0598
# 4  0.0762  0.0666  0.0481  0.0394  0.0590  0.0649  0.1209  0.2467  0.3564
#
#       a10  ...     a52     a53     a54     a55     a56     a57     a58  \
# 0  0.2111  ...  0.0027  0.0065  0.0159  0.0072  0.0167  0.0180  0.0084
# 1  0.2872  ...  0.0084  0.0089  0.0048  0.0094  0.0191  0.0140  0.0049
# 2  0.6194  ...  0.0232  0.0166  0.0095  0.0180  0.0244  0.0316  0.0164
# 3  0.1264  ...  0.0121  0.0036  0.0150  0.0085  0.0073  0.0050  0.0044
# 4  0.4459  ...  0.0031  0.0054  0.0105  0.0110  0.0015  0.0072  0.0048
#
#       a59     a60  R
# 0  0.0090  0.0032  1
# 1  0.0052  0.0044  1
# 2  0.0095  0.0078  1
# ...

# %%
# Let's now check the outliers and clean the data.

from scipy.stats import zscore
z = np.abs(zscore(df_sonar))
z
# Out:
# array([[0.39955135, 0.04064823, 0.02692565, ..., 0.17167808, 0.65894689,
#         1.06973356],
#        [0.70353822, 0.42163039, 1.05561832, ..., 0.44455424, 0.41985233,
#         1.06973356],
#        [0.12922901, 0.60106749, 1.72340448, ..., 0.25276128, 0.25758223,
#         1.06973356],
#        ...,
#        [1.00438083, 0.16007801, 0.67384349, ..., 0.03913824, 0.67887143,
#         0.93481221],
#        [0.04953255, 0.09539176, 0.13480381, ..., 0.70402047, 0.34015415,
#         0.93481221],
#        [0.13794908, 0.06497869, 0.78861924, ..., 0.29860448, 0.99479044,
#         0.93481221]])

# %%
z.shape
# Out:
# (208, 61)

# %%
df_sonar_final = df_sonar.loc[(z<3).all(axis=1)]
df_sonar_final.shape
# Out:
# (168, 61)

# %%
# by comparing shape of 'z' and 'df_sonar_final' shape , 40 points have been removed as an outlier.

# %%
#Lets seprate the input and output variable
x=df_sonar.drop(columns=["R"])
y=df_sonar[["R"]]

# %%
# Scaling down using Standardscaler.

from sklearn.preprocessing import StandardScaler
sc = StandardScaler()
x = sc.fit_transform(x)
x
# Out:
# array([[-0.39955135, -0.04064823, -0.02692565, ...,  0.06987027,
#          0.17167808, -0.65894689],
#        [ 0.70353822,  0.42163039,  1.05561832, ..., -0.47240644,
#         -0.44455424, -0.41985233],
#        [-0.12922901,  0.60106749,  1.72340448, ...,  1.30935987,
#          0.25276128,  0.25758223],
#        ...,
#        [ 1.00438083,  0.16007801, -0.67384349, ...,  0.90652575,
#         -0.03913824, -0.67887143],
#        [ 0.04953255, -0.09539176,  0.13480381, ..., -0.00759783,
#         -0.70402047, -0.34015415],
#        [-0.13794908, -0.06497869, -0.78861924, ..., -0.6738235 ,
#         -0.29860448,  0.99479044]])

# %%
from sklearn.model_selection import train_test_split
from sklearn.metrics import mean_absolute_error
from sklearn.metrics import mean_squared_error
from sklearn.metrics import r2_score
from sklearn import linear_model

# %%
max_r_score=0
for r_state in range(42,100):
    x_train, x_test, y_train, y_test = train_test_split(x, y, random_state = r_state, test_size = 0.20)
    regr = linear_model.LinearRegression()
    regr.fit(x_train, y_train)
    y_pred = regr.predict(x_test)
    r2_scr = r2_score(y_test, y_pred)
    print("r2 score corresponding to random state: ", r_state,"is: ", r2_scr)
    if r2_scr>max_r_score:
        max_r_score = r2_scr
        final_r_state = r_state
        
print("max r2 score corresponding to ",final_r_state," is : ",max_r_score)
# Out:
# r2 score corresponding to random state:  42 is:  0.28215397687321
# r2 score corresponding to random state:  43 is:  -0.21345746279022637
# r2 score corresponding to random state:  44 is:  0.2243704053526896
# r2 score corresponding to random state:  45 is:  0.08101811513897506
# r2 score corresponding to random state:  46 is:  0.09167495234778633
# r2 score corresponding to random state:  47 is:  -0.0017484853066760397
# r2 score corresponding to random state:  48 is:  -0.04186044594184746
# r2 score corresponding to random state:  49 is:  -0.34062053145152493
# r2 score corresponding to random state:  50 is:  -0.07694781473195289
# r2 score corresponding to random state:  51 is:  -0.09391865320193493
# r2 score corresponding to random state:  52 is:  -0.09737837832383889
# r2 score corresponding to random state:  53 is:  0.005525986234353297
# r2 score corresponding to random state:  54 is:  -0.18296751916465226
# ...

# %%
# Lets do the cross validation
from sklearn.model_selection import cross_val_score
cross_val_score(linear_model.LinearRegression(), x, y, cv=5, scoring = "r2").mean()
# Out:
# -0.2217595129112711

# %%
# Thus creating the final model.
x_train, x_test, y_train, y_test = train_test_split(x, y, random_state = r_state, test_size = 0.20)
lr = linear_model.LinearRegression()
lr.fit(x_train, y_train)
y_pred = regr.predict(x_test)

# %%
# Lets evaluate RMSE and r2 score using sklearn library
import numpy as np
print("r2 score is : ",r2_score(y_test, y_pred))
print("RMSE is : ",np.sqrt(mean_squared_error(y_test, y_pred)))
# Out:
# r2 score is :  0.21847151723835145
# RMSE is :  0.44001130355948087

# %%
# saving the model using joblib
from sklearn.externals import joblib

# Save the model as a pickle in a file
joblib.dump(lr, 'lr_sonar.pkl')
# Out:
# ['lr_sonar.pkl']
